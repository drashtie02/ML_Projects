# %%
import pandas as pd

df = pd.read_csv('E:\\Drashti\\Machine Learning\\Regression\\User_Data.csv')

df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
df.select_dtypes('object')
# Out:
#      Gender
# 0      Male
# 1      Male
# 2    Female
# 3    Female
# 4      Male
# ..      ...
# 395  Female
# 396    Male
# 397  Female
# 398    Male
# 399  Female
#
# [400 rows x 1 columns]

# %% [markdown]
# USE OF HEAD() METHOD(TOP 5)

# %%
df.head()
# Out:
#   Month   "Average"   "2005"   "2006"   "2007"   "2008"   "2009"   "2010"  \
# 0   May         0.1        0        0        1        1        0        0
# 1   Jun         0.5        2        1        1        0        0        1
# 2   Jul         0.7        5        1        1        2        0        1
# 3   Aug         2.3        6        3        2        4        4        4
# 4   Sep         3.5        6        4        7        4        2        8
#
#     "2011"   "2012"   "2013"   "2014"   "2015"
# 0        0        2        0        0        0
# 1        1        2        2        0        1
# 2        3        0        2        2        1
# 3        7        8        2        2        3
# 4        5        2        5        2        5

# %% [markdown]
#  USE OF TAIL() METHOD (LAST 5)

# %%
df.tail()
# Out:
#   Month   "Average"   "2005"   "2006"   "2007"   "2008"   "2009"   "2010"  \
# 3   Aug         2.3        6        3        2        4        4        4
# 4   Sep         3.5        6        4        7        4        2        8
# 5   Oct         2.0        8        0        1        3        2        5
# 6   Nov         0.5        3        0        0        1        1        0
# 7   Dec         0.0        1        0        1        0        0        0
#
#     "2011"   "2012"   "2013"   "2014"   "2015"
# 3        7        8        2        2        3
# 4        5        2        5        2        5
# 5        1        5        2        3        0
# 6        1        0        1        0        1
# 7        0        0        0        0        1

# %%
df.tail(3)
# Out:
#   Month   "Average"   "2005"   "2006"   "2007"   "2008"   "2009"   "2010"  \
# 5   Oct         2.0        8        0        1        3        2        5
# 6   Nov         0.5        3        0        0        1        1        0
# 7   Dec         0.0        1        0        1        0        0        0
#
#     "2011"   "2012"   "2013"   "2014"   "2015"
# 5        1        5        2        3        0
# 6        1        0        1        0        1
# 7        0        0        0        0        1

# %%
df.head(3)
# Out:
#   Month   "Average"   "2005"   "2006"   "2007"   "2008"   "2009"   "2010"  \
# 0   May         0.1        0        0        1        1        0        0
# 1   Jun         0.5        2        1        1        0        0        1
# 2   Jul         0.7        5        1        1        2        0        1
#
#     "2011"   "2012"   "2013"   "2014"   "2015"
# 0        0        2        0        0        0
# 1        1        2        2        0        1
# 2        3        0        2        2        1

# %% [markdown]
# INFO()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       8 non-null      object
#  1    "Average"  8 non-null      float64
#  2    "2005"     8 non-null      int64
#  3    "2006"     8 non-null      int64
#  4    "2007"     8 non-null      int64
#  5    "2008"     8 non-null      int64
#  6    "2009"     8 non-null      int64
#  7    "2010"     8 non-null      int64
#  8    "2011"     8 non-null      int64
#  9    "2012"     8 non-null      int64
#  10   "2013"     8 non-null      int64
#  11   "2014"     8 non-null      int64
#  12   "2015"     8 non-null      int64
# dtypes: float64(1), int64(11), object(1)
# memory usage: 964.0+ bytes

# %% [markdown]
# DESCRIBE()

# %%
df.describe()
# Out:
#        "Average"    "2005"    "2006"    "2007"    "2008"    "2009"    "2010"  \
# count   8.000000  8.000000  8.000000  8.000000  8.000000  8.000000  8.000000
# mean    1.200000  3.875000  1.125000  1.750000  1.875000  1.125000  2.375000
# std     1.254705  2.799872  1.552648  2.187628  1.642081  1.457738  2.973094
# min     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25%     0.400000  1.750000  0.000000  1.000000  0.750000  0.000000  0.000000
# 50%     0.600000  4.000000  0.500000  1.000000  1.500000  0.500000  1.000000
# 75%     2.075000  6.000000  1.500000  1.250000  3.250000  2.000000  4.250000
# max     3.500000  8.000000  4.000000  7.000000  4.000000  4.000000  8.000000
#
#         "2011"    "2012"    "2013"    "2014"    "2015"
# count  8.00000  8.000000  8.000000  8.000000  8.000000
# mean   2.25000  2.375000  1.750000  1.125000  1.500000
# std    2.54951  2.825269  1.581139  1.246423  1.690309
# ...

# %% [markdown]
# RENAME COLUMNS NAME

# %%
df.rename(columns={'Gender':'sex'},inplace= True)

# %%
df.head()
# Out:
#     User ID     sex  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.columns
# Out:
# Index(['User ID', 'sex', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %% [markdown]
# ACCESS COLUMNS

# %%
df.Purchased[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Purchased, dtype: int64

# %% [markdown]
# ACCESS DATA BY INDEX VALUES

# %%
df.loc[1]
# Out:
# User ID            15810944
# sex                    Male
# Age                      35
# EstimatedSalary       20000
# Purchased                 0
# Name: 1, dtype: object

# %%
df.loc[1:4]
# Out:
#     User ID     sex  Age  EstimatedSalary  Purchased
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.iloc[1]
# Out:
# User ID            15810944
# sex                    Male
# Age                      35
# EstimatedSalary       20000
# Purchased                 0
# Name: 1, dtype: object

# %% [markdown]
# THE DIFERANCE BETWEEN LOC AND ILOC IS LOC WILL TAKE INDEX VALUES AND ILOC WILL TAKE NUMBERS

# %%
df.iloc[1:3]
# Out:
#     User ID     sex  Age  EstimatedSalary  Purchased
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %% [markdown]
# FILTERING ROWS BASED ON COMDITIONS

# %%
df[(df['Age']>59)]
# Out:
#       User ID     sex  Age  EstimatedSalary  Purchased
# 215  15779529  Female   60           108000          1
# 223  15593715    Male   60           102000          1
# 272  15791373    Male   60            42000          1
# 355  15606472    Male   60            34000          1
# 370  15611430  Female   60            46000          1
# 371  15774744    Male   60            83000          1
# 393  15635893    Male   60            42000          1

# %%
df[((df['Age']>59) & (df['EstimatedSalary']>100000))]
# Out:
#       User ID     sex  Age  EstimatedSalary  Purchased
# 215  15779529  Female   60           108000          1
# 223  15593715    Male   60           102000          1
