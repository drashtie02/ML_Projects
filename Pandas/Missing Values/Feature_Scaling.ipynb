# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.DataFrame({'WEIGHT':[15,18,12,10],
                   'PRICE':[1,3,2,5]}, 
                   index = ['Orange','Apple','Banana','Grape'])

print(df)
# Out:
#         WEIGHT  PRICE
# Orange      15      1
# Apple       18      3
# Banana      12      2
# Grape       10      5

# %%
from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()

# %%
scaling.fit_transform(df[['WEIGHT','PRICE']])
# Out:
# array([[0.625, 0.   ],
#        [1.   , 0.5  ],
#        [0.25 , 0.25 ],
#        [0.   , 1.   ]])

# %%
df1 = pd.DataFrame(scaling.fit_transform(df),
                   columns = ['WEIGHT','PRICE'],
                   index = ['Orange','Apple','Banana','Grape'])

# %%
ax = df.plot.scatter(x='WEIGHT',y= 'PRICE',color = ['red','green','blue','yellow'],
                     marker = '*',s = 80 , label = 'BEFORE SCALING') 

df1.plot.scatter(x='WEIGHT',y = 'PRICE',color = ['red','green','blue','yellow'],
                 marker = 'o',s = 60 ,label = 'AFTER SCALING', ax = ax) 

plt.axhline(0, color='red' ,alpha=0.2)
plt.axvline(0, color='red' ,alpha=0.2)

# %% [markdown]
# STANDARD SCALING (ZERO
# )

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit_transform(df[['WEIGHT','PRICE']])
# Out:
# array([[ 0.41239305, -1.18321596],
#        [ 1.40213637,  0.16903085],
#        [-0.57735027, -0.50709255],
#        [-1.23717915,  1.52127766]])

# %%
df1 = pd.DataFrame(scaler.fit_transform(df),
                   columns = ['WEIGHT','PRICE'],
                   index = ['Orange','Apple','Banana','Grape'])

# %%
ax = df.plot.scatter(x='WEIGHT',y= 'PRICE',color = ['red','green','blue','yellow'],
                     marker = '*',s = 80 , label = 'BEFORE SCALING') 

df1.plot.scatter(x='WEIGHT',y = 'PRICE',color = ['red','green','blue','yellow'],
                 marker = 'o',s = 60 ,label = 'AFTER SCALING', ax = ax) 

plt.axhline(0, color='red' ,alpha=0.9)
plt.axvline(0, color='red' ,alpha=0.2)
